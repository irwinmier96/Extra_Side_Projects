# %%
# Using Pandas to analyze a dataframe of countries
import pandas as pd

# %%
facts = "factbook.csv"

# %%
factbook = pd.read_csv(facts, sep = ";")

# %%
factbook
# Out:
#                          Country Area(sq km)  \
# 0                         String      double
# 1                    Afghanistan      647500
# 2                       Akrotiri         123
# 3                        Albania       28748
# 4                        Algeria     2381740
# 5                 American Samoa         199
# 6                        Andorra         468
# 7                         Angola     1246700
# 8                       Anguilla         102
# 9                     Antarctica    14000000
# 10           Antigua and Barbuda         443
# 11                     Argentina     2766890
# 12                       Armenia       29800
# 13                         Aruba         193
# 14   Ashmore and Cartier Islands           5
# 15                     Australia     7686850
# 16                       Austria       83870
# 17                    Azerbaijan       86600
# 18                   Bahamas The       13940
# 19                       Bahrain         665
# ...

# %% [markdown]
# #Dropping the first line of the dataset
# facts_df = factbook.drop(factbook.index[0])
# facts_df

# %%
#Dropping the first line of the dataset 
facts_df = factbook.drop(factbook.index[0])
facts_df
# Out:
#                          Country Area(sq km)  \
# 1                    Afghanistan      647500
# 2                       Akrotiri         123
# 3                        Albania       28748
# 4                        Algeria     2381740
# 5                 American Samoa         199
# 6                        Andorra         468
# 7                         Angola     1246700
# 8                       Anguilla         102
# 9                     Antarctica    14000000
# 10           Antigua and Barbuda         443
# 11                     Argentina     2766890
# 12                       Armenia       29800
# 13                         Aruba         193
# 14   Ashmore and Cartier Islands           5
# 15                     Australia     7686850
# 16                       Austria       83870
# 17                    Azerbaijan       86600
# 18                   Bahamas The       13940
# 19                       Bahrain         665
# 20                  Baker Island           1
# ...

# %%
largest_area = facts_df["Area(sq km)"].max()
largest_area
# Out:
# '9984670'

# %%
large_nations_area = facts_df["Area(sq km)"] = 500000
