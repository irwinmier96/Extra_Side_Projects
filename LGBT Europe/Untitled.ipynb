# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
disc = pd.read_csv("Datasets/LGBT_Survey_Discrimination.csv")
disc
# Out:
#           CountryCode          subset question_code  \
# 0             Austria         Lesbian           c10
# 1             Austria         Lesbian           c10
# 2             Austria         Lesbian           c10
# 3             Austria         Lesbian           c10
# 4             Austria         Lesbian           c10
# 5             Austria         Lesbian           c10
# 6             Austria         Lesbian           c10
# 7             Austria         Lesbian           c10
# 8             Austria         Lesbian           c10
# 9             Austria             Gay           c10
# 10            Austria             Gay           c10
# 11            Austria             Gay           c10
# 12            Austria             Gay           c10
# 13            Austria             Gay           c10
# 14            Austria             Gay           c10
# 15            Austria             Gay           c10
# 16            Austria             Gay           c10
# ...

# %%
#separate datasets by country and question: Compare a western European country to an Eastern European country
#Germany and Romania
#pick three questions
germany = disc[disc["CountryCode"] == "Germany"]
