# %%
#Europe LGBT Survey Analysis
#Questions to consider
#make datasets specific for each dataset?

#Daily Life Survey specific 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dailylife = pd.read_csv("Datasets/LGBT_Survey_DailyLife.csv")
dailylife
# Out:
#           CountryCode          subset  question_code  \
# 0             Austria         Lesbian           b1_a
# 1             Austria         Lesbian           b1_a
# 2             Austria         Lesbian           b1_a
# 3             Austria         Lesbian           b1_a
# 4             Austria         Lesbian           b1_a
# 5             Austria             Gay           b1_a
# 6             Austria             Gay           b1_a
# 7             Austria             Gay           b1_a
# 8             Austria             Gay           b1_a
# 9             Austria             Gay           b1_a
# 10            Austria  Bisexual women           b1_a
# 11            Austria  Bisexual women           b1_a
# 12            Austria  Bisexual women           b1_a
# 13            Austria  Bisexual women           b1_a
# 14            Austria  Bisexual women           b1_a
# 15            Austria    Bisexual men           b1_a
# 16            Austria    Bisexual men           b1_a
# ...

# %%
#analyze by question, group by question given to participants. 
#maybe do select countries?

#Find out countries that were listed
countries = dailylife.groupby("CountryCode").count()
countries
# Out:
#                 subset  question_code  question_label  answer  percentage  \
# CountryCode
# Austria           1180           1180            1180    1180        1180
# Average           1184           1184            1184    1184        1184
# Belgium           1179           1179            1179    1179        1179
# Bulgaria          1170           1170            1170    1170        1170
# Croatia           1163           1163            1163    1163        1163
# Cyprus            1158           1158            1158    1158        1158
# Czech Republic    1179           1179            1179    1179        1179
# Denmark           1175           1175            1175    1175        1175
# Estonia           1152           1152            1152    1152        1152
# Finland           1180           1180            1180    1180        1180
# France            1180           1180            1180    1180        1180
# ...

# %%
#Find out questions listed
questions = dailylife.loc[:, ["question_code", "question_label"]]
questions

#Select specific questions since there are so many of them to choose
# Out:
# For each of the following types of discrimination, could you please specify whether, in your opinion, it is very rare, fairly rare, fairly widespread or very widespread in the country where you live?                                                                         1450
# All things considered, how satisfied would you say you are with your life these days? *                                                                                                                                                                                         1412
# Have you been open about you being L, G, B or T? *                                                                                                                                                                                                                               870
# ...
